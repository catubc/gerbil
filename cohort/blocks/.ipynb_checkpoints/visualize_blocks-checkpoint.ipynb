# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

#
import sys
sys.path.append('/home/cat/code/gerbil/')

# 
from utils.track import track

# %%
# Load database 
database = pd.read_excel('/mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/database.xlsx')


# Choose day you want to plot
day = 'P23'

db = database[database['Dev Day'] == day]
blocks = db['Slp filename'].to_numpy(dtype = str)

print(f"Number of files for {day}: {blocks.shape}")    # Note that this is going to include Both files twice (one for day, one for night)
# Out:
# Number of files for P23: (66,)

# %%
plt.figure(figsize = (9,7))

plt.title(f'Blocks: {day}')

plt.tight_layout()

blocks = ['block1', 'block2']
colors = ['#ccbb44', '#228833']

plt.xlim(0,900)
plt.xticks([0,100,200,300,400,500,600,700,800,900])

plt.ylim(-700,0)
plt.yticks(ticks = [-700,-600,-500,-400,-300,-200,-100,0], labels = [0,100,200,300,400,500,600,700])

fnames = [
    '/mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_21_05_53_58_206226_compressed_Night.npy',
    '/mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_21_06_16_09_243773_compressed_Night.npy'
]

root_dir = '/mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/'
fnames = os.listdir(root_dir)

for i, fname in enumerate(fnames):
#for i, f in enumerate(blocks):
    fname = os.path.join(root_dir, fname)
    #fname = os.path.join(root_dir,str(f))[:-3]+'npy'
    print (fname)
    
    try:
        locations = np.load(fname)
        
    except:
        print('no file')
                                
    for ((ctr, a),c) in zip((enumerate(blocks)),colors):
        
        try:
            plt.plot(locations[:,:,0,ctr],(-locations[:,:,1,ctr]), "o", color = c, label = a) #, linewidth = 6)
        
        except:
            print('index error')
    
plt.savefig("/home/cat/code/blocks.png", transparent=True)
# Out:
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_20_09_53_59_813912_compressed_Day.npy

# %%
#
root_dir = '/mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/'
fnames = os.listdir(root_dir)

# for i, fname in enumerate(fnames):
for i, f in enumerate(blocks):
    # fname = os.path.join(root_dir, fname)
    fname = os.path.join(root_dir,str(f))
    print (fname)
    
    if os.path.exists(fname):
    
        fname_spine_out = fname.replace('.slp',".npy")
        if os.path.exists(fname_spine_out):
            continue

        t = track.Track(fname)
    
    #
    t.track_type = "blocks'
    
    # try:
    t.load_tracks()
    
    locations = t.tracks_centers
    print ("Locations: ", locations.shape)
    # locations = np.load(fname)
        
#     except:
#         print('no file')
                           
    # locations =  locations.squeeze()
    print (locations.shape)
    
    def get_clean_block(block):
    
        # REMOVE SHORT CHUNKS likely error
        vals = block.sum(1)
        min_len = 24

        #
        inside=False
        ctr=0
        if np.isnan(vals[0])==False:
            start = 0
            inside=True
            
        #
        for k in range(1,vals.shape[0],1):
            #print (inside, vals[k])
            if inside:
                if np.isnan(vals[k]):
                    if (k-start)<min_len:
                        block[start:k]=np.nan
                        ctr+=1

                    inside=False
            else:
                if np.isnan(vals[k])==False:
                    start = k
                    inside=True

        print ("removed # of chunks: ", ctr)       

        # REMOVE BIG JUMPS FROM VISUALIZATION
        # Number of pixels of movement allowed in between sequential time points
        threshold=5

        #
        dists = block[1:]-block[:-1]
        #print (block1)
        lens = np.linalg.norm(dists,axis=1)
        print (lens.shape)
        idx = np.where(lens>threshold)[0]

        for id_ in idx:
            block[id_-1:id_+1]=np.nan

        return block
            
    # plot 1st block
    block1 = get_clean_block(locations[:,0])
    plt.plot(block1[:,0],
             block1[:,1])
    
    # plot 2nd block
    block2 = get_clean_block(locations[:,1])
    plt.plot(block2[:,0],
             block2[:,1])
    
    #
    plt.xlim(0,1080)
    plt.ylim(0,900)
#plt.savefig("/home/cat/code/blocks.png", transparent=True)
# Out:
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_10_24_741354_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_32_39_783450_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_54_44_481249_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 2)
# 	track_occupancy: (2, 28802)
# 	point_scores: (28802, 1, 2)
# 	instance_scores: (28802, 2)
# 	tracking_scores: (28802, 2)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_00_54_44_481249_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_00_54_44_481249_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_00_54_44_481249_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_00_54_44_481249_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_00_54_44_481249_compressed_Night.slp", "total_elapsed": 1082.9987165927887, "start_timestamp": "2023-04-17 14:56:51.074055", "finish_timestamp": "2023-04-17 15:14:54.072755", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_00_54_44_481249_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_00_54_44_481249_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_54_44_481249_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 2, 2)
# (28802, 2, 2)
# removed # of chunks:  0
# (28801,)
# removed # of chunks:  0
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_01_16_54_904448_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 2)
# 	track_occupancy: (2, 28802)
# 	point_scores: (28802, 1, 2)
# 	instance_scores: (28802, 2)
# 	tracking_scores: (28802, 2)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_01_16_54_904448_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_01_16_54_904448_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_01_16_54_904448_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_01_16_54_904448_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_01_16_54_904448_compressed_Night.slp", "total_elapsed": 1073.4091050624847, "start_timestamp": "2023-04-13 20:26:04.810214", "finish_timestamp": "2023-04-13 20:43:58.219297", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_01_16_54_904448_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_01_16_54_904448_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_01_16_54_904448_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 2, 2)
# (28802, 2, 2)
# removed # of chunks:  2
# (28801,)
# removed # of chunks:  1
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_01_39_06_376883_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 207
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 207)
# 	track_occupancy: (207, 28802)
# 	point_scores: (28802, 1, 207)
# 	instance_scores: (28802, 207)
# 	tracking_scores: (28802, 207)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_01_39_06_376883_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_01_39_06_376883_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_01_39_06_376883_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_01_39_06_376883_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_01_39_06_376883_compressed_Night.slp", "total_elapsed": 966.7686796188354, "start_timestamp": "2023-04-17 14:18:50.094980", "finish_timestamp": "2023-04-17 14:34:56.863640", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_01_39_06_376883_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_01_39_06_376883_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_01_39_06_376883_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 207, 2)
# (28802, 207, 2)
# removed # of chunks:  1
# (28801,)
# removed # of chunks:  0
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_01_19_002918_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 217
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 217)
# 	track_occupancy: (217, 28802)
# 	point_scores: (28802, 1, 217)
# 	instance_scores: (28802, 217)
# 	tracking_scores: (28802, 217)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_02_01_19_002918_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_02_01_19_002918_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_02_01_19_002918_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_02_01_19_002918_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_02_01_19_002918_compressed_Night.slp", "total_elapsed": 935.1725029945374, "start_timestamp": "2023-04-12 09:28:09.011823", "finish_timestamp": "2023-04-12 09:43:44.184307", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_02_01_19_002918_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_02_01_19_002918_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_01_19_002918_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 217, 2)
# (28802, 217, 2)
# removed # of chunks:  15
# (28801,)
# removed # of chunks:  3
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_23_30_823259_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 198
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 198)
# 	track_occupancy: (198, 28802)
# 	point_scores: (28802, 1, 198)
# 	instance_scores: (28802, 198)
# 	tracking_scores: (28802, 198)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_02_23_30_823259_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_02_23_30_823259_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_02_23_30_823259_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_02_23_30_823259_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_02_23_30_823259_compressed_Night.slp", "total_elapsed": 935.5176653862, "start_timestamp": "2023-04-17 14:02:47.656302", "finish_timestamp": "2023-04-17 14:18:23.173949", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_02_23_30_823259_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_02_23_30_823259_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_23_30_823259_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 198, 2)
# (28802, 198, 2)
# removed # of chunks:  40
# (28801,)
# removed # of chunks:  31
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_45_46_902455_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 162
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 162)
# 	track_occupancy: (162, 28802)
# 	point_scores: (28802, 1, 162)
# 	instance_scores: (28802, 162)
# 	tracking_scores: (28802, 162)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_02_45_46_902455_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_02_45_46_902455_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_02_45_46_902455_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_02_45_46_902455_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_02_45_46_902455_compressed_Night.slp", "total_elapsed": 933.4691667556763, "start_timestamp": "2023-03-31 15:06:49.004093", "finish_timestamp": "2023-03-31 15:22:22.473244", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_02_45_46_902455_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_02_45_46_902455_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_45_46_902455_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 162, 2)
# (28802, 162, 2)
# removed # of chunks:  18
# (28801,)
# removed # of chunks:  13
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_07_55_372616_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 249
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 249)
# 	track_occupancy: (249, 28802)
# 	point_scores: (28802, 1, 249)
# 	instance_scores: (28802, 249)
# 	tracking_scores: (28802, 249)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_03_07_55_372616_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_03_07_55_372616_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_03_07_55_372616_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_03_07_55_372616_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_03_07_55_372616_compressed_Night.slp", "total_elapsed": 941.8781323432922, "start_timestamp": "2023-04-11 16:33:38.551196", "finish_timestamp": "2023-04-11 16:49:20.429312", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_03_07_55_372616_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_03_07_55_372616_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_07_55_372616_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 249, 2)
# (28802, 249, 2)
# removed # of chunks:  21
# (28801,)
# removed # of chunks:  18
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_30_00_549597_compressed_Night.slp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4848/1346865268.py in <module>
#      18
#      19     # try:
# ---> 20     t.load_tracks()
#      21
#      22     locations = t.tracks_centers
#
# ~/code/gerbil/utils/track/track.py in load_tracks(self)
#     126             if self.verbose:
#     127                 print("... npy missing, converting...")
# --> 128             self.slp_to_npy()
#     129             if self.verbose:
#     130                 print("... done loading npy")
#
# ~/code/gerbil/utils/track/track.py in slp_to_npy(self)
#      77             if self.verbose:
#      78                 print("... h5 file missing, converting now...")
# ---> 79             self.slp_to_h5()
#      80             if self.verbose:
#      81                 print("... done loading h5")
#
# ~/code/gerbil/utils/track/track.py in slp_to_h5(self, overwrite)
#      69                 print("... done loading slp")
#      70
# ---> 71         self.slp.export(fname_h5)
#      72
#      73     def slp_to_npy(self):
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/sleap/io/dataset.py in export(self, filename)
#    2051         from sleap.io.format.sleap_analysis import SleapAnalysisAdaptor
#    2052
# -> 2053         SleapAnalysisAdaptor.write(filename, self)
#    2054
#    2055     def export_nwb(
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/sleap/io/format/sleap_analysis.py in write(cls, filename, source_object, source_path, video)
#     149             labels_path=source_path,
#     150             all_frames=True,
# --> 151             video=video,
#     152         )
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/sleap/info/write_tracking_h5.py in main(labels, output_path, labels_path, all_frames, video)
#     328             instance_scores,
#     329             tracking_scores,
# --> 330         ) = get_occupancy_and_points_matrices(labels, all_frames, video)
#     331     except TypeError:
#     332         print(
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/sleap/info/write_tracking_h5.py in get_occupancy_and_points_matrices(labels, all_frames, video)
#     146                     inst for inst in predicted_instances if inst.track == track
#     147                 ]
# --> 148                 if len(predicted_track_instances) > 0:
#     149                     track_instances = predicted_track_instances
#     150
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f3955cfe950> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib_inline/backend_inline.py in show(close, block)
#      90             display(
#      91                 figure_manager.canvas.figure,
# ---> 92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      93             )
#      94     finally:
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2293                 )
#    2294                 with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2295                     self.figure.draw(renderer)
#    2296
#    2297             if bbox_inches:
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    2844             self.patch.draw(renderer)
#    2845             mimage._draw_list_compositing_images(
# -> 2846                 renderer, self, artists, self.suppressComposite)
#    2847
#    2848             for sfig in self.subfigs:
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3090
#    3091         mimage._draw_list_compositing_images(
# -> 3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#    3094         renderer.close_group('axes')
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1156         renderer.open_group(__name__, gid=self.get_gid())
#    1157
# -> 1158         ticks_to_draw = self._update_ticks()
#    1159         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                                 renderer)
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/axis.py in _update_ticks(self)
#    1051             tick.set_label1(label)
#    1052             tick.set_label2(label)
# -> 1053         minor_locs = self.get_minorticklocs()
#    1054         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1055         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1280         """Return this Axis' minor tick locations in data coordinates."""
#    1281         # Remove minor ticks duplicating major ticks.
# -> 1282         major_locs = self.major.locator()
#    1283         minor_locs = self.minor.locator()
#    1284         transform = self._scale.get_transform()
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/ticker.py in __call__(self)
#    2113     def __call__(self):
#    2114         vmin, vmax = self.axis.get_view_interval()
# -> 2115         return self.tick_values(vmin, vmax)
#    2116
#    2117     def tick_values(self, vmin, vmax):
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2121         vmin, vmax = mtransforms.nonsingular(
#    2122             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2123         locs = self._raw_ticks(vmin, vmax)
#    2124
#    2125         prune = self._prune
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2060         if self._nbins == 'auto':
#    2061             if self.axis is not None:
# -> 2062                 nbins = np.clip(self.axis.get_tick_space(),
#    2063                                 max(1, self._min_n_ticks - 1), 9)
#    2064             else:
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/axis.py in get_tick_space(self)
#    2521
#    2522     def get_tick_space(self):
# -> 2523         ends = mtransforms.Bbox.from_bounds(0, 0, 1, 1)
#    2524         ends = ends.transformed(self.axes.transAxes -
#    2525                                 self.figure.dpi_scale_trans)
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/transforms.py in from_bounds(x0, y0, width, height)
#     818         *width* and *height* may be negative.
#     819         """
# --> 820         return Bbox.from_extents(x0, y0, x0 + width, y0 + height)
#     821
#     822     @staticmethod
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/matplotlib/transforms.py in from_extents(minpos, *args)
#     837            scales where negative bounds result in floating point errors.
#     838         """
# --> 839         bbox = Bbox(np.reshape(args, (2, 2)))
#     840         if minpos is not None:
#     841             bbox._minpos[:] = minpos
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      53     bound = getattr(obj, method, None)
#      54     if bound is None:
# ---> 55         return _wrapit(obj, method, *args, **kwds)
#      56
#      57     try:
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      42     except AttributeError:
#      43         wrap = None
# ---> 44     result = getattr(asarray(obj), method)(*args, **kwds)
#      45     if wrap:
#      46         if not isinstance(result, mu.ndarray):
#
# ~/miniconda3/envs/sleap_new/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# KeyboardInterrupt:
