# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

#
import sys
sys.path.append('/home/cat/code/gerbil/')

# 
from utils.track import track

# %%
# Load database 
database = pd.read_excel('/mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/database.xlsx')


# Choose day you want to plot
day = 'P23'

db = database[database['Dev Day'] == day]
blocks = db['Slp filename'].to_numpy(dtype = str)

print(f"Number of files for {day}: {blocks.shape}")    # Note that this is going to include Both files twice (one for day, one for night)
# Out:
# Number of files for P23: (66,)

# %%
plt.figure(figsize = (9,7))

plt.title(f'Blocks: {day}')

plt.tight_layout()

blockss = ['block1', 'block2']
colors = ['#ccbb44', '#228833']

plt.xlim(0,900)
plt.xticks([0,100,200,300,400,500,600,700,800,900])

plt.ylim(-700,0)
plt.yticks(ticks = [-700,-600,-500,-400,-300,-200,-100,0], labels = [0,100,200,300,400,500,600,700])

root_dir = '/mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/'
# fnames = os.listdir(root_dir)

# for i, fname in enumerate(fnames):
for i, f in enumerate(blocks):
    # fname = os.path.join(root_dir, fname)
    fname = os.path.join(root_dir,str(f))[:-3]+'npy'
    print (fname)
    
    try:
        locations = np.load(fname)
        
    except:
        print('no file')
                                
    for ((ctr, a),c) in zip((enumerate(blockss)),colors):
        
        try:
            print(locations.shape)
            plt.plot(locations[:,ctr,:,0],(-locations[:,ctr,:,1]), "o", color = c, label = a) #, linewidth = 6)
        
        except:
            print('index error')
    
plt.savefig("/home/cat/code/blocks.png", transparent=True)
# Out:
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_10_24_741354_compressed_Night.npy
# (28802, 16, 1, 2)
# (28802, 16, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_32_39_783450_compressed_Night.npy
# (28802, 10, 1, 2)
# (28802, 10, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_54_44_481249_compressed_Night.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_01_16_54_904448_compressed_Night.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_01_39_06_376883_compressed_Night.npy
# (28802, 207, 1, 2)
# (28802, 207, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_01_19_002918_compressed_Night.npy
# (28802, 217, 1, 2)
# (28802, 217, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_23_30_823259_compressed_Night.npy
# (28802, 198, 1, 2)
# (28802, 198, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_45_46_902455_compressed_Night.npy
# (28802, 162, 1, 2)
# (28802, 162, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_07_55_372616_compressed_Night.npy
# (28802, 249, 1, 2)
# (28802, 249, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_30_00_549597_compressed_Night.npy
# (28802, 313, 1, 2)
# (28802, 313, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_52_16_413367_compressed_Night.npy
# (28802, 354, 1, 2)
# (28802, 354, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_14_20_966669_compressed_Night.npy
# (28802, 9, 1, 2)
# (28802, 9, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_36_32_061173_compressed_Night.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_58_44_677386_compressed_Night.npy
# (28802, 5, 1, 2)
# (28802, 5, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_05_20_58_282764_compressed_Night.npy
# (28802, 43, 1, 2)
# (28802, 43, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_05_43_10_443827_compressed_Night.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_05_26_127241_compressed_Night.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_27_30_409518_compressed_Night.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_49_45_915749_compressed_Night.npy
# (28802, 98, 1, 2)
# (28802, 98, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_11_50_790944_compressed_Night.npy
# (28802, 18, 1, 2)
# (28802, 18, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_34_01_186542_compressed_Night.npy
# (28802, 14, 1, 2)
# (28802, 14, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_56_12_916962_compressed_Day.npy
# no file
# (28802, 14, 1, 2)
# (28802, 14, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_56_12_916962_compressed_Night.npy
# (28802, 3, 1, 2)
# (28802, 3, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_08_18_22_807978_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_08_40_33_404833_compressed_Day.npy
# (28802, 4, 1, 2)
# (28802, 4, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_09_02_44_753509_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_09_24_56_211972_compressed_Day.npy
# (28802, 4, 1, 2)
# (28802, 4, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_09_47_11_800576_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_10_09_15_689003_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_10_31_28_278398_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_10_53_40_742147_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_11_15_51_029878_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_11_38_02_143208_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_12_00_15_017915_compressed_Day.npy
# (28802, 6, 1, 2)
# (28802, 6, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_12_22_27_018688_compressed_Day.npy
# (28802, 6, 1, 2)
# (28802, 6, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_12_44_39_153311_compressed_Day.npy
# (28802, 4, 1, 2)
# (28802, 4, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_13_06_53_109088_compressed_Day.npy
# (28802, 26, 1, 2)
# (28802, 26, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_13_29_05_407195_compressed_Day.npy
# (28802, 41, 1, 2)
# (28802, 41, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_13_51_19_879553_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_14_13_23_483319_compressed_Day.npy
# (28802, 7, 1, 2)
# (28802, 7, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_14_35_34_975355_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_14_57_47_914114_compressed_Day.npy
# (28802, 2, 1, 2)
# (28802, 2, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_15_20_01_136026_compressed_Day.npy
# (28802, 12, 1, 2)
# (28802, 12, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_15_42_15_445145_compressed_Day.npy
# (28802, 26, 1, 2)
# (28802, 26, 1, 2)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_16_04_27_918376_compressed_Day.npy
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_16_26_39_554930_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_16_48_52_536179_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_17_11_05_340439_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_17_33_18_702387_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_17_55_30_032341_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_18_17_44_492890_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_18_39_56_344474_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_19_02_07_728860_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_19_24_18_841647_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_19_46_30_220311_compressed_Day.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_20_08_43_002789_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_20_30_55_988179_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_20_53_12_384889_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_21_15_17_530807_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_21_37_31_760604_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_21_59_44_286086_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_22_21_57_246040_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_22_44_11_314502_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_23_06_17_572564_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_23_28_28_927799_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_23_50_42_142475_compressed_Night.npy
# no file
# (28802, 1, 1, 2)
# (28802, 1, 1, 2)
# index error

# %%
#
root_dir = '/mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/'
fnames = os.listdir(root_dir)

# for i, fname in enumerate(fnames):
for i, f in enumerate(blocks):
    # fname = os.path.join(root_dir, fname)
    fname = os.path.join(root_dir,str(f))
    print (fname)
    
    if os.path.exists(fname):
    
        fname_spine_out = fname.replace('.slp',".npy")
        if os.path.exists(fname_spine_out):
            continue

        t = track.Track(fname)
    
    #
    t.track_type = "blocks"
    
    # try:
    t.load_tracks()
    
    locations = t.tracks_centers
    print ("Locations: ", locations.shape)
    # locations = np.load(fname)
        
#     except:
#         print('no file')
                           
    # locations =  locations.squeeze()
    print (locations.shape)
    
    def get_clean_block(block):
    
        # REMOVE SHORT CHUNKS likely error
        vals = block.sum(1)
        min_len = 24

        #
        inside=False
        ctr=0
        if np.isnan(vals[0])==False:
            start = 0
            inside=True
            
        #
        for k in range(1,vals.shape[0],1):
            #print (inside, vals[k])
            if inside:
                if np.isnan(vals[k]):
                    if (k-start)<min_len:
                        block[start:k]=np.nan
                        ctr+=1

                    inside=False
            else:
                if np.isnan(vals[k])==False:
                    start = k
                    inside=True

        print ("removed # of chunks: ", ctr)       

        # REMOVE BIG JUMPS FROM VISUALIZATION
        # Number of pixels of movement allowed in between sequential time points
        threshold=5

        #
        dists = block[1:]-block[:-1]
        #print (block1)
        lens = np.linalg.norm(dists,axis=1)
        print (lens.shape)
        idx = np.where(lens>threshold)[0]

        for id_ in idx:
            block[id_-1:id_+1]=np.nan

        return block
            
    # plot 1st block
    block1 = get_clean_block(locations[:,0])
    plt.plot(block1[:,0],
             block1[:,1])
    
    # plot 2nd block
    block2 = get_clean_block(locations[:,1])
    plt.plot(block2[:,0],
             block2[:,1])
    
    #
    plt.xlim(0,1080)
    plt.ylim(0,900)
#plt.savefig("/home/cat/code/blocks.png", transparent=True)
# Out:
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_10_24_741354_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_32_39_783450_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_00_54_44_481249_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_01_16_54_904448_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_01_39_06_376883_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_01_19_002918_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_23_30_823259_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_02_45_46_902455_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_07_55_372616_compressed_Night.slp
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_30_00_549597_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 313
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 313)
# 	track_occupancy: (313, 28802)
# 	point_scores: (28802, 1, 313)
# 	instance_scores: (28802, 313)
# 	tracking_scores: (28802, 313)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_03_30_00_549597_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_03_30_00_549597_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_03_30_00_549597_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_03_30_00_549597_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_03_30_00_549597_compressed_Night.slp", "total_elapsed": 905.7553074359894, "start_timestamp": "2023-04-04 12:13:53.752745", "finish_timestamp": "2023-04-04 12:28:59.508037", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_03_30_00_549597_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_03_30_00_549597_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_30_00_549597_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 313, 2)
# (28802, 313, 2)
# removed # of chunks:  2
# (28801,)
# removed # of chunks:  1
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_52_16_413367_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 354
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 354)
# 	track_occupancy: (354, 28802)
# 	point_scores: (28802, 1, 354)
# 	instance_scores: (28802, 354)
# 	tracking_scores: (28802, 354)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_03_52_16_413367_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_03_52_16_413367_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_03_52_16_413367_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_03_52_16_413367_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_03_52_16_413367_compressed_Night.slp", "total_elapsed": 927.4456660747528, "start_timestamp": "2023-04-04 23:46:04.894289", "finish_timestamp": "2023-04-05 00:01:32.339938", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_03_52_16_413367_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_03_52_16_413367_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_03_52_16_413367_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 354, 2)
# (28802, 354, 2)
# removed # of chunks:  63
# (28801,)
# removed # of chunks:  9
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_14_20_966669_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 9
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 9)
# 	track_occupancy: (9, 28802)
# 	point_scores: (28802, 1, 9)
# 	instance_scores: (28802, 9)
# 	tracking_scores: (28802, 9)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_04_14_20_966669_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_04_14_20_966669_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_04_14_20_966669_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_04_14_20_966669_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_04_14_20_966669_compressed_Night.slp", "total_elapsed": 948.5136783123016, "start_timestamp": "2023-04-12 10:07:45.584716", "finish_timestamp": "2023-04-12 10:23:34.098375", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_04_14_20_966669_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_04_14_20_966669_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_14_20_966669_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 9, 2)
# (28802, 9, 2)
# removed # of chunks:  819
# (28801,)
# removed # of chunks:  756
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_36_32_061173_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 2)
# 	track_occupancy: (2, 28802)
# 	point_scores: (28802, 1, 2)
# 	instance_scores: (28802, 2)
# 	tracking_scores: (28802, 2)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_04_36_32_061173_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_04_36_32_061173_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_04_36_32_061173_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_04_36_32_061173_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_04_36_32_061173_compressed_Night.slp", "total_elapsed": 933.4777648448944, "start_timestamp": "2023-04-06 16:54:34.541373", "finish_timestamp": "2023-04-06 17:10:08.019119", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_04_36_32_061173_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_04_36_32_061173_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_36_32_061173_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 2, 2)
# (28802, 2, 2)
# removed # of chunks:  1
# (28801,)
# removed # of chunks:  2
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_58_44_677386_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 5
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 5)
# 	track_occupancy: (5, 28802)
# 	point_scores: (28802, 1, 5)
# 	instance_scores: (28802, 5)
# 	tracking_scores: (28802, 5)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_04_58_44_677386_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_04_58_44_677386_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_04_58_44_677386_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_04_58_44_677386_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_04_58_44_677386_compressed_Night.slp", "total_elapsed": 916.7104432582855, "start_timestamp": "2023-03-31 19:42:32.797631", "finish_timestamp": "2023-03-31 19:57:49.508056", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_04_58_44_677386_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_04_58_44_677386_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_04_58_44_677386_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 5, 2)
# (28802, 5, 2)
# removed # of chunks:  1
# (28801,)
# removed # of chunks:  19
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_05_20_58_282764_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 43
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 43)
# 	track_occupancy: (43, 28802)
# 	point_scores: (28802, 1, 43)
# 	instance_scores: (28802, 43)
# 	tracking_scores: (28802, 43)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_05_20_58_282764_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_05_20_58_282764_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_05_20_58_282764_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_05_20_58_282764_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_05_20_58_282764_compressed_Night.slp", "total_elapsed": 1032.6954469680786, "start_timestamp": "2023-04-13 18:16:33.715153", "finish_timestamp": "2023-04-13 18:33:46.410582", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_05_20_58_282764_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_05_20_58_282764_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_05_20_58_282764_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 43, 2)
# (28802, 43, 2)
# removed # of chunks:  1
# (28801,)
# removed # of chunks:  22
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_05_43_10_443827_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 2)
# 	track_occupancy: (2, 28802)
# 	point_scores: (28802, 1, 2)
# 	instance_scores: (28802, 2)
# 	tracking_scores: (28802, 2)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_05_43_10_443827_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_05_43_10_443827_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_05_43_10_443827_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_05_43_10_443827_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_05_43_10_443827_compressed_Night.slp", "total_elapsed": 1058.555909872055, "start_timestamp": "2023-04-17 14:08:49.917780", "finish_timestamp": "2023-04-17 14:26:28.473672", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_05_43_10_443827_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_05_43_10_443827_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_05_43_10_443827_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 2, 2)
# (28802, 2, 2)
# removed # of chunks:  0
# (28801,)
# removed # of chunks:  0
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_05_26_127241_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 2)
# 	track_occupancy: (2, 28802)
# 	point_scores: (28802, 1, 2)
# 	instance_scores: (28802, 2)
# 	tracking_scores: (28802, 2)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_06_05_26_127241_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_06_05_26_127241_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_06_05_26_127241_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_06_05_26_127241_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_06_05_26_127241_compressed_Night.slp", "total_elapsed": 1070.1693885326385, "start_timestamp": "2023-04-17 13:38:07.654193", "finish_timestamp": "2023-04-17 13:55:57.823560", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_06_05_26_127241_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_06_05_26_127241_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_05_26_127241_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 2, 2)
# (28802, 2, 2)
# removed # of chunks:  0
# (28801,)
# removed # of chunks:  0
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_27_30_409518_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 2)
# 	track_occupancy: (2, 28802)
# 	point_scores: (28802, 1, 2)
# 	instance_scores: (28802, 2)
# 	tracking_scores: (28802, 2)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_06_27_30_409518_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_06_27_30_409518_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_06_27_30_409518_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_06_27_30_409518_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_06_27_30_409518_compressed_Night.slp", "total_elapsed": 1052.6870493888855, "start_timestamp": "2023-04-08 01:08:34.093987", "finish_timestamp": "2023-04-08 01:26:06.781017", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_06_27_30_409518_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_06_27_30_409518_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_27_30_409518_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 2, 2)
# (28802, 2, 2)
# removed # of chunks:  4
# (28801,)
# removed # of chunks:  0
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_49_45_915749_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 98
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 98)
# 	track_occupancy: (98, 28802)
# 	point_scores: (28802, 1, 98)
# 	instance_scores: (28802, 98)
# 	tracking_scores: (28802, 98)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_06_49_45_915749_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_06_49_45_915749_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_06_49_45_915749_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_06_49_45_915749_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_06_49_45_915749_compressed_Night.slp", "total_elapsed": 1017.2615807056427, "start_timestamp": "2023-04-03 16:17:44.480852", "finish_timestamp": "2023-04-03 16:34:41.742405", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_06_49_45_915749_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_06_49_45_915749_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_06_49_45_915749_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 98, 2)
# (28802, 98, 2)
# removed # of chunks:  13
# (28801,)
# removed # of chunks:  27
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_11_50_790944_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 18
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 18)
# 	track_occupancy: (18, 28802)
# 	point_scores: (28802, 1, 18)
# 	instance_scores: (28802, 18)
# 	tracking_scores: (28802, 18)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_07_11_50_790944_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_07_11_50_790944_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_07_11_50_790944_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_07_11_50_790944_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_07_11_50_790944_compressed_Night.slp", "total_elapsed": 1045.8251564502716, "start_timestamp": "2023-04-13 09:17:19.143086", "finish_timestamp": "2023-04-13 09:34:44.968220", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_07_11_50_790944_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_07_11_50_790944_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_11_50_790944_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 18, 2)
# (28802, 18, 2)
# removed # of chunks:  4
# (28801,)
# removed # of chunks:  0
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_34_01_186542_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 14
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 14)
# 	track_occupancy: (14, 28802)
# 	point_scores: (28802, 1, 14)
# 	instance_scores: (28802, 14)
# 	tracking_scores: (28802, 14)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_07_34_01_186542_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_07_34_01_186542_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_07_34_01_186542_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_07_34_01_186542_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_07_34_01_186542_compressed_Night.slp", "total_elapsed": 1046.2223405838013, "start_timestamp": "2023-04-10 17:23:58.737709", "finish_timestamp": "2023-04-10 17:41:24.960030", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_07_34_01_186542_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_07_34_01_186542_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_34_01_186542_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 14, 2)
# (28802, 14, 2)
# removed # of chunks:  4
# (28801,)
# removed # of chunks:  2
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_56_12_916962_compressed_Day.slp
# spine missing can't be computed
# Locations:  (28802, 14, 2)
# (28802, 14, 2)
# removed # of chunks:  4
# (28801,)
# removed # of chunks:  2
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_56_12_916962_compressed_Night.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 3
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 3)
# 	track_occupancy: (3, 28802)
# 	point_scores: (28802, 1, 3)
# 	instance_scores: (28802, 3)
# 	tracking_scores: (28802, 3)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_07_56_12_916962_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night/training_config.json", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_07_56_12_916962_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night -m /vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night -o /vast/cm5635/cohort2/blocks/2020_07_28_07_56_12_916962_compressed_Night.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_07_56_12_916962_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_07_56_12_916962_compressed_Night.slp", "total_elapsed": 968.245635509491, "start_timestamp": "2023-04-14 13:22:18.136058", "finish_timestamp": "2023-04-14 13:38:26.381675", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_07_56_12_916962_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/night/blocks.centered_instance_night", "/vast/cm5635/cohort2/blocks/models/night/blocks.centroid_night"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_07_56_12_916962_compressed_Night.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_07_56_12_916962_compressed_Night.h5
# spine missing can't be computed
# Locations:  (28802, 3, 2)
# (28802, 3, 2)
# removed # of chunks:  0
# (28801,)
# removed # of chunks:  1
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_08_18_22_807978_compressed_Day.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 2)
# 	track_occupancy: (2, 28802)
# 	point_scores: (28802, 1, 2)
# 	instance_scores: (28802, 2)
# 	tracking_scores: (28802, 2)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_08_18_22_807978_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# ...
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_14_35_34_975355_compressed_Day.h5
# spine missing can't be computed
# Locations:  (28802, 2, 2)
# (28802, 2, 2)
# removed # of chunks:  0
# (28801,)
# removed # of chunks:  0
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_14_57_47_914114_compressed_Day.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 2
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 2)
# 	track_occupancy: (2, 28802)
# 	point_scores: (28802, 1, 2)
# 	instance_scores: (28802, 2)
# 	tracking_scores: (28802, 2)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_14_57_47_914114_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day/training_config.json", "/vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_14_57_47_914114_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day -m /vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day -o /vast/cm5635/cohort2/blocks/2020_07_28_14_57_47_914114_compressed_Day.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_14_57_47_914114_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_14_57_47_914114_compressed_Day.slp", "total_elapsed": 1034.9427511692047, "start_timestamp": "2023-04-11 10:22:46.584214", "finish_timestamp": "2023-04-11 10:40:01.526944", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_14_57_47_914114_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day", "/vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_14_57_47_914114_compressed_Day.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_14_57_47_914114_compressed_Day.h5
# spine missing can't be computed
# Locations:  (28802, 2, 2)
# (28802, 2, 2)
# removed # of chunks:  8
# (28801,)
# removed # of chunks:  0
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_15_20_01_136026_compressed_Day.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 12
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 12)
# 	track_occupancy: (12, 28802)
# 	point_scores: (28802, 1, 12)
# 	instance_scores: (28802, 12)
# 	tracking_scores: (28802, 12)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_15_20_01_136026_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day/training_config.json", "/vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_15_20_01_136026_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day -m /vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day -o /vast/cm5635/cohort2/blocks/2020_07_28_15_20_01_136026_compressed_Day.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_15_20_01_136026_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_15_20_01_136026_compressed_Day.slp", "total_elapsed": 932.2971532344818, "start_timestamp": "2023-04-12 09:46:44.887616", "finish_timestamp": "2023-04-12 10:02:17.184750", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_15_20_01_136026_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day", "/vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_15_20_01_136026_compressed_Day.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_15_20_01_136026_compressed_Day.h5
# spine missing can't be computed
# Locations:  (28802, 12, 2)
# (28802, 12, 2)
# removed # of chunks:  0
# (28801,)
# removed # of chunks:  14
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_15_42_15_445145_compressed_Day.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 26
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 26)
# 	track_occupancy: (26, 28802)
# 	point_scores: (28802, 1, 26)
# 	instance_scores: (28802, 26)
# 	tracking_scores: (28802, 26)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_15_42_15_445145_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day/training_config.json", "/vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_15_42_15_445145_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day -m /vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day -o /vast/cm5635/cohort2/blocks/2020_07_28_15_42_15_445145_compressed_Day.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_15_42_15_445145_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_15_42_15_445145_compressed_Day.slp", "total_elapsed": 936.2800872325897, "start_timestamp": "2023-04-17 13:43:09.585346", "finish_timestamp": "2023-04-17 13:58:45.865418", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_15_42_15_445145_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day", "/vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_15_42_15_445145_compressed_Day.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_15_42_15_445145_compressed_Day.h5
# spine missing can't be computed
# Locations:  (28802, 26, 2)
# (28802, 26, 2)
# removed # of chunks:  0
# (28801,)
# removed # of chunks:  8
# (28801,)
# /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_16_04_27_918376_compressed_Day.slp
#
# Exporting to SLEAP Analysis file...
# 	track_names: 1
# 	node_names: 1
# 	edge_names: 0
# 	edge_inds: 0
# 	tracks: (28802, 1, 2, 1)
# 	track_occupancy: (1, 28802)
# 	point_scores: (28802, 1, 1)
# 	instance_scores: (28802, 1)
# 	tracking_scores: (28802, 1)
# 	labels_path: None
# 	video_path: /vast/cm5635/cohort2/videos/2020_07_28_16_04_27_918376_compressed_defished_shrink_cropped.mp4
# 	video_ind: 0
# 	provenance: {"model_paths": ["/vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day/training_config.json", "/vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day/training_config.json"], "predictor": "TopDownPredictor", "sleap_version": "1.3.0a0", "platform": "Linux-4.18.0-372.26.1.el8_6.x86_64-x86_64-with-debian-buster-sid", "command": "/vast/cm5635/environments/sleap_liezl/bin/sleap-track /vast/cm5635/cohort2/videos/2020_07_28_16_04_27_918376_compressed_defished_shrink_cropped.mp4 -m /vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day -m /vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day -o /vast/cm5635/cohort2/blocks/2020_07_28_16_04_27_918376_compressed_Day.slp --tracking.tracker simple --tracking.target_instance_count 2 --tracking.pre_cull_to_target 1 --tracking.pre_cull_iou_threshold 0.8 --tracking.post_connect_single_breaks 1", "data_path": "/vast/cm5635/cohort2/videos/2020_07_28_16_04_27_918376_compressed_defished_shrink_cropped.mp4", "output_path": "/vast/cm5635/cohort2/blocks/2020_07_28_16_04_27_918376_compressed_Day.slp", "total_elapsed": 930.0839598178864, "start_timestamp": "2023-04-14 13:03:34.918472", "finish_timestamp": "2023-04-14 13:19:05.002415", "args": {"data_path": "/vast/cm5635/cohort2/videos/2020_07_28_16_04_27_918376_compressed_defished_shrink_cropped.mp4", "models": ["/vast/cm5635/cohort2/blocks/models/day/blocks.centered_instance_day", "/vast/cm5635/cohort2/blocks/models/day/blocks.centroid_day"], "frames": "", "only_labeled_frames": false, "only_suggested_frames": false, "output": "/vast/cm5635/cohort2/blocks/2020_07_28_16_04_27_918376_compressed_Day.slp", "no_empty_frames": false, "verbosity": "rich", "video.dataset": null, "video.input_format": "channels_last", "video.index": "", "cpu": false, "first_gpu": false, "last_gpu": false, "gpu": "auto", "max_edge_length_ratio": 0.25, "dist_penalty_weight": 1.0, "batch_size": 4, "open_in_gui": false, "peak_threshold": 0.2, "tracking.tracker": "simple", "tracking.target_instance_count": 2, "tracking.pre_cull_to_target": 1, "tracking.pre_cull_iou_threshold": 0.8, "tracking.post_connect_single_breaks": 1, "tracking.clean_instance_count": null, "tracking.clean_iou_threshold": null, "tracking.similarity": null, "tracking.match": null, "tracking.robust": null, "tracking.track_window": null, "tracking.min_new_track_points": null, "tracking.min_match_points": null, "tracking.img_scale": null, "tracking.of_window_size": null, "tracking.of_max_levels": null, "tracking.save_shifted_instances": null, "tracking.kf_node_indices": null, "tracking.kf_init_frame_count": null}}
# Saved as /mnt/b3a68699-495d-4ebb-9ab1-ac74f11c68c5/gerbil/cohort2/blocks/2020_07_28_16_04_27_918376_compressed_Day.h5
# spine missing can't be computed
# Locations:  (28802, 1, 2)
# (28802, 1, 2)
# removed # of chunks:  46
# (28801,)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_4848/1690690580.py in <module>
#      85
#      86     # plot 2nd block
# ---> 87     block2 = get_clean_block(locations[:,1])
#      88     plt.plot(block2[:,0],
#      89              block2[:,1])
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
